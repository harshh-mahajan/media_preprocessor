# %%
from media_preprocessor import img_pre

# %%
six = img_pre('D:/PROJECT/umpire six',128,False)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(8, 3))
for i in range(10):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(six[i].reshape(128,128), cmap=plt.cm.bone)

# %%
six = img_pre('D:/PROJECT/umpire six',128,True)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(8, 3))
for i in range(10):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(six[i].reshape(128,128), cmap=plt.cm.bone)

# %%
from media_preprocessor import nbg_vc

# %%
img = nbg_vc(512)
